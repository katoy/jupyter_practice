# %%
# See also
#    http://delta0726.web.fc2.com/library_py/jupyter.html

import os
import pandas as pd

# base_url = 'https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/'
base_url = "./sample-data/anime/"

anime_csv = os.path.join(base_url, 'anime.csv')
anime_tsv = os.path.join(base_url, 'anime.tsv')
anime_xlsx = os.path.join(base_url, 'anime.xlsx')

anime_master_csv =  os.path.join(base_url, 'anime_master.csv')
anime_split_genre_csv =  os.path.join(base_url, 'anime_split_genre.csv')
anime_genre_top10_csv =  os.path.join(base_url, 'anime_genre_top10.csv')
anime_genre_top10_povoted_csv =  os.path.join(base_url, 'anime_genre_top10_pivoted.csv')
anime_stock_price_csv =  os.path.join(base_url, 'anime_stock_price.csv')
anime_stock_returns_csv =  os.path.join(base_url, 'anime_stock_returns.csv')
t4816_csv = os.path.join(base_url, '4816.csv')
t3791_csv = os.path.join(base_url, '3791.csv')
n225_csv = os.path.join(base_url, 'n225.csv')

pd.read_csv(anime_csv).head()
pd.read_csv(anime_master_csv).head()
pd.read_csv(anime_split_genre_csv).head()
pd.read_csv(anime_genre_top10_csv).head()
pd.read_csv(anime_genre_top10_povoted_csv).head()
pd.read_csv(anime_stock_price_csv,index_col=0, parse_dates=['Date']).head()
pd.read_csv(anime_stock_returns_csv,index_col=0, parse_dates=['Date']).head()
pd.read_csv(t4816_csv).head()
pd.read_csv(t3791_csv).head()
pd.read_csv(n225_csv).head()
pd.read_csv(anime_tsv, sep='\t')
pd.read_excel(anime_xlsx, sheetnae='Movie')

url = 'https://docs.python.org/3/py-modindex.html'
tables = pd.read_html(url, index_col=1)
tables[0].loc[:, 1:].dropna().head(10)
# Out:
#                                                                2
# 1
# __future__                          Future statement definitions
# __main__       The environment where the top-level script is ...
# _dummy_thread        Drop-in replacement for the _thread module.
# _thread                                 Low-level threading API.
# abc                 Abstract base classes according to PEP 3119.
# aifc           Read and write audio files in AIFF or AIFC for...
# argparse       Command-line option and argument parsing library.
# array          Space efficient arrays of uniformly typed nume...
# ast               Abstract Syntax Tree classes and manipulation.
# asynchat       Support for asynchronous command/response prot...

# %%
import pandas as pd
import matplotlib.pyplot as plt

base_url = 'https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/'
anime_stock_returns_csv = os.path.join(base_url, 'anime_stock_returns.csv')
anime_stock_returns_df = pd.read_csv(anime_stock_returns_csv, index_col=0)
ax = anime_stock_returns_df.plot()
ax.set_title('stock returns')
plt.show()

# %%
df = pd.read_csv(anime_csv)

# データセットから演算子を使ってデータ抽出
df.loc[df['episodes'] == 'Unknown']
# Out:
#        anime_id                                               name  \
# 73           21                                          One Piece
# 248         235                                    Detective Conan
# 607        1735                                 Naruto: Shippuuden
# 993       33157             Tanaka-kun wa Itsumo Kedaruge Specials
# 1226      21639                                    Yu☆Gi☆Oh! Arc-V
# 1262       8687                                    Doraemon (2005)
# 1851      32410                    Dimension W: W no Tobira Online
# 1853      30694                                  Dragon Ball Super
# 1908      32977                                 Aggressive Retsuko
# 1943       6149                           Chibi Maruko-chan (1995)
# 1981      23539                                           Gudetama
# 2251      34178                         Inazuma Eleven: Outer Code
# 2402      34034                             Pokemon Sun &amp; Moon
# 2575       1199                                   Nintama Rantarou
# 2591      32717                                     Aikatsu Stars!
# 2624      34077                       Cardfight!! Vanguard G: Next
# 2656      23135                                            PriPara
# 2783      33490                            Kaitou Joker 4th Season
# 2876       7643                                           Domo-kun
# 2880      13163           Furusato Saisei: Nihon no Mukashibanashi
# 3349      19157                                       Youkai Watch
# 4376      32829                                Nobunaga no Shinobi
# 5223                                                Game       TV  Unknown
# ...                                                  ...      ...      ...
# 10437                                              Drama      NaN  Unknown
# 10438                     Action, Fantasy, Magic, School       TV  Unknown
# 10439                                                NaN       TV  Unknown
# 10440  Action, Adventure, Comedy, Drama, Josei, Super...       TV  Unknown
# 10441                                             Comedy       TV  Unknown
# 10442         Mystery, School, Super Power, Supernatural       TV  Unknown
# 10443                     Action, Drama, Fantasy, Sci-Fi       TV  Unknown
# 10444                                     Action, School       TV  Unknown
# 10445                                                NaN      NaN  Unknown
# 10447                              Action, Music, Sci-Fi       TV  Unknown
# 10448                              Action, Music, Sci-Fi       TV  Unknown
# 10449                                             Comedy       TV  Unknown
# 10452               Horror, School, Seinen, Supernatural       TV  Unknown
# 10453                                       Drama, Josei       TV  Unknown
# 10454                    Drama, Fantasy, Romance, Sci-Fi       TV  Unknown
# 10455                       Music, School, Slice of Life       TV  Unknown
# 10458                                             Seinen       TV  Unknown
# 10462                       Music, School, Slice of Life       TV  Unknown
# 10463                                Action, Super Power       TV  Unknown
# 10464                   Adventure, Comedy, Fantasy, Kids       TV  Unknown
# 10467                                            Fantasy      OVA  Unknown
# 10469                                                NaN       TV  Unknown
# 10471              Comedy, Drama, Fantasy, Slice of Life       TV  Unknown
# 10472             Action, Drama, Military, Sci-Fi, Space      OVA  Unknown
# 10473            Action, Fantasy, Magic, Sci-Fi, Shounen      NaN  Unknown
# 10474                      Comedy, Seinen, Slice of Life       TV  Unknown
# 10476                                       Drama, Music       TV  Unknown
# 10477                            School, Shounen, Sports      ONA  Unknown
# 10478                     Dementia, Horror, Supernatural       TV  Unknown
# 10479                                    Magic, Military       TV  Unknown
#
#        rating  members
# 73       8.58   504862
# 248      8.25   114702
# 607      7.94   533578
# 993      7.72     5400
# 1226     7.61    17571
# 1262     7.59     2980
# 1851     7.40     4799
# 1853     7.40   111443
# 1908     7.38     5465
# 1943     7.37     1113
# 1981     7.36     2348
# 2251     7.28     1072
# 2402     7.23    11030
# 2575     7.18     2255
# 2591     7.17     4485
# 2624     7.16     1363
# 2656     7.17     7680
# 2783     7.12     1178
# 2876     7.09     1167
# 2880     7.09     6820
# 3349     6.95     8147
# 4376     6.65     7207
# 4498     6.61      359
# 4513     6.61      940
# 4597     6.57     3437
# 4964     6.48      515
# 5005     6.46      515
# 5085     6.44     8652
# 5163     6.41     3676
# 5223     6.39      912
# ...       ...      ...
# 10437     NaN       65
# 10438     NaN     4174
# 10439     NaN      219
# 10440     NaN     1286
# 10441     NaN     1295
# 10442     NaN     2076
# 10443     NaN      416
# 10444     NaN     1465
# 10445     NaN     1797
# 10447     NaN     1880
# 10448     NaN     1556
# 10449     NaN       43
# 10452     NaN     3165
# 10453     NaN     8585
# 10454     NaN      251
# 10455     NaN     2504
# 10458     NaN     6474
# 10462     NaN      359
# 10463     NaN      242
# 10464     NaN      107
# 10467     NaN     4481
# 10469     NaN      843
# 10471     NaN     5934
# 10472     NaN     2058
# 10473     NaN     2341
# 10474     NaN     4305
# 10476     NaN      381
# 10477     NaN      381
# 10478     NaN     1838
# 10479     NaN     6652
#
# [290 rows x 7 columns]

# %%
import os
import pandas as pd
from urllib.request import urlopen
import sqlite3

base_url = "./sample-data/anime/"
anime_db = os.path.join(base_url, 'anime.db')

df = None
with sqlite3.connect(anime_db) as conn:
    df = pd.read_sql('SELECT * FROM anime', conn)
    # conn.close

df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266
